# %% [markdown]
# ## Observations and Insights

# %%
# OBSERVATIONS: 
#     1. Capomulin and Ramicane seem to be the most frequently used drug regimens.
#     2. When we look at the Capomulin regimen, it seems that there is correlation between weight and tumor size.
#           The heavier the mouse, the larger the tumor.
#     3. When we look at the Capomulin regimen, it is clear that the longer a mouse is on on treatment,
#           the smaller the tumor gets.

# %%
# %matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df = pd.DataFrame(pd.merge(mouse_metadata, study_results, on='Mouse ID', how='outer'))
# Display the data table for preview
merged_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
print(merged_df['Mouse ID'].nunique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicates = merged_df[merged_df.duplicated(['Mouse ID','Timepoint'],keep=False)]
dmid = duplicates['Mouse ID'].unique()
dmid
# Out:
# array(['g989'], dtype=object)

# %%
# reset index to mouse id
merged_df = merged_df.set_index('Mouse ID')
merged_df
# Out:
#          Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# k403         Ramicane  Male          21          16          0
# k403         Ramicane  Male          21          16          5
# k403         Ramicane  Male          21          16         10
# k403         Ramicane  Male          21          16         15
# k403         Ramicane  Male          21          16         20
# ...               ...   ...         ...         ...        ...
# z969         Naftisol  Male           9          30         25
# z969         Naftisol  Male           9          30         30
# z969         Naftisol  Male           9          30         35
# z969         Naftisol  Male           9          30         40
# z969         Naftisol  Male           9          30         45
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# k403               45.000000                 0
# k403               38.825898                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dmid_data = merged_df.loc[dmid]
dmid_data
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         25
# g989         Propriva  Female          21          26         30
# g989         Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merged_df
clean_df.drop(clean_df.loc[dmid].index,inplace=True)
clean_df = clean_df.reset_index()
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1875     z969     Naftisol  Male           9          30         25
# 1876     z969     Naftisol  Male           9          30         30
# 1877     z969     Naftisol  Male           9          30         35
# 1878     z969     Naftisol  Male           9          30         40
# 1879     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
print(clean_df['Mouse ID'].nunique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance,
# standard deviation, and SEM of the tumor volume for each regimen
regimen_data = clean_df.groupby(['Drug Regimen'])
reg_groups_mean = regimen_data['Tumor Volume (mm3)'].mean()
reg_groups_std = regimen_data['Tumor Volume (mm3)'].std()
reg_groups_median = regimen_data['Tumor Volume (mm3)'].median()
reg_groups_var = regimen_data['Tumor Volume (mm3)'].var()
reg_groups_sem = regimen_data['Tumor Volume (mm3)'].sem()
# This method is the most straighforward,
# creating multiple series and putting them all together at the end.
summary_sts = pd.DataFrame({'Mean': reg_groups_mean, 'Standard Deviation':reg_groups_std,
                            'Median': reg_groups_median, 'Variance': reg_groups_var, 'SEM':reg_groups_sem})
summary_sts
# Out:
#                    Mean  Standard Deviation     Median   Variance       SEM
# Drug Regimen
# Capomulin     40.675741            4.994774  41.557809  24.947764  0.329346
# Ceftamin      52.591172            6.268188  51.776157  39.290177  0.469821
# Infubinol     52.884795            6.567243  51.820584  43.128684  0.492236
# Ketapril      55.235638            8.279709  53.698743  68.553577  0.603860
# Naftisol      54.331565            8.134708  52.509285  66.173479  0.596466
# Placebo       54.033581            7.821003  52.288934  61.168083  0.581331
# Propriva      52.320930            6.622085  50.446266  43.852013  0.544332
# Ramicane      40.216745            4.846308  40.673236  23.486704  0.320955
# Stelasyn      54.233149            7.710419  52.431737  59.450562  0.573111
# Zoniferol     53.236507            6.966589  51.818479  48.533355  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
tx_per_reg = clean_df.groupby(['Drug Regimen']).count()['Mouse ID']
tx_per_reg.plot(kind='bar',title='Cancer Treatment Frequency by Regimen',rot=45)
plt.ylabel('Treatment Count')
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender = clean_df.groupby(['Sex']).nunique()['Mouse ID'].plot(kind='pie',title='Gender Distribution',autopct='%.1f%%')
plt.ylabel('')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# gender = clean_df.groupby(['Sex']).nunique()['Mouse ID']
# pie(gender, axis=equal,labels=gender.index)
# show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
select_treatments = clean_df[clean_df['Drug Regimen'].isin(['Capomulin','Ramicane','Infubinol','Ceftamin'])]
select_treatments = select_treatments.sort_values(['Timepoint'],ascending=False)
select_treatments
# Start by getting the last (greatest) timepoint for each mouse
max_tp_mid = select_treatments.groupby(['Mouse ID']).first()
# max_tp_mid

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merge_clean_max_tp = pd.DataFrame(pd.merge(clean_df, max_tp_mid, on = 'Mouse ID', how='outer'))
merge_clean_max_tp
# Out:
#      Mouse ID Drug Regimen_x Sex_x  Age_months_x  Weight (g)_x  Timepoint_x  \
# 0        k403       Ramicane  Male            21            16            0
# 1        k403       Ramicane  Male            21            16            5
# 2        k403       Ramicane  Male            21            16           10
# 3        k403       Ramicane  Male            21            16           15
# 4        k403       Ramicane  Male            21            16           20
# ...       ...            ...   ...           ...           ...          ...
# 1875     z969       Naftisol  Male             9            30           25
# 1876     z969       Naftisol  Male             9            30           30
# 1877     z969       Naftisol  Male             9            30           35
# 1878     z969       Naftisol  Male             9            30           40
# 1879     z969       Naftisol  Male             9            30           45
#
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
top_tx_names = ['Capomulin','Ramicane','Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
final = merge_clean_max_tp


    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
mid_capomulin = clean_df[clean_df['Mouse ID'].isin(['y793'])].reset_index()
line_plot = mid_capomulin[['Mouse ID','Drug Regimen','Timepoint','Tumor Volume (mm3)']]
lp = line_plot.plot.line()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
all_capomulin = clean_df[clean_df['Drug Regimen'].isin(['Capomulin'])].reset_index()
all_capomulin = all_capomulin[['Drug Regimen', 'Mouse ID', 'Weight (g)', 'Tumor Volume (mm3)']]

weight = all_capomulin.groupby('Weight (g)')['Tumor Volume (mm3)'].mean()
weight_df = pd.DataFrame(weight).reset_index()

capo_sp = weight_df.plot.scatter(x='Weight (g)',y='Tumor Volume (mm3)',title='Capomulin Regimen',grid=True)

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# I don't understand what correlation and regression mean 
# so I couldn't do this part.
